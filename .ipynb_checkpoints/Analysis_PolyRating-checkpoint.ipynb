# %%
import json 
import pandas as pd
import numpy as np

raw_df = pd.read_json("polyrating.json",orient='columns')

def flatten(a):
    try:
        return a[0]
    except:
        return a
    
def explode(df, lst_cols, fill_value=''):
    # make sure `lst_cols` is a list
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)

    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()

    if (lens > 0).all():
        # ALL lists in cells aren't empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        # at least one list in cells is empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]

# %%
raw_df1 = explode(raw_df,"reviews")
split_review = raw_df1["reviews"].apply(pd.Series)
df = raw_df1.join(split_review)

# %%
df = df.drop("reviews",axis=1)

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Make rating numeric

# %%
df["agg_rating"] = pd.to_numeric(df["agg_rating"].str[:4], errors="coerce")

# %%
def get_course_num(course):
    if len(course) == 2:
        return course[1]
    else:
        return course

df["year"] = df["date"].str.extract('(\d+)')
df["month"] = df["date"].str[:3]
df["course_num"] = pd.to_numeric(df["class"].str.split("_").apply(get_course_num))
df["level"] = pd.to_numeric(df['course_num'].astype(str).str[0] + "00")

df = df[(df["course_num"] > 99) & (df["course_num"] < 551)]

# %% [markdown]
# ## Average Grade by Year

# %%
df["gpa"] = df.grade.map({
    "A":4,
    "B":3,
    "C":2,
    "D":1,
    "F":0
})

# %%
df.groupby("standing")["gpa"].mean()[["Freshman", "Sophomore", "Junior", "Senior"]].plot.bar(ylim=(3.05, 3.25))

# %% [markdown]
# ## Average Rating of Professor by Year

# %%
df.groupby("standing")["agg_rating"].mean()[["Freshman", "Sophomore", "Junior", "Senior"]].plot.bar(ylim=(2.4, 2.75))

# %% [markdown]
# ## Polyrating vs. Average Grade

# %%
profs = df["prof_name"].value_counts()[df["prof_name"].value_counts() > 30].to_frame().index.tolist()
high_rating_count = df[(df["prof_name"].isin(profs))]

# %%
professor_means = high_rating_count.groupby("prof_name")[["agg_rating","gpa"]].mean()
high_rating_count.groupby("prof_name")[["agg_rating","gpa"]].mean().plot.scatter(x="agg_rating", y="gpa")

# %%
import seaborn as sns
import math

avg_rev_len = high_rating_count.groupby("prof_name")["review"].apply(lambda x: np.mean(x.str.len()))
professor_means["avg_rev_len"] = avg_rev_len
sns.lmplot(x="agg_rating", y="gpa", data=professor_means, fit_reg=True)
professor_means["log_transform"] = np.log(professor_means["avg_rev_len"])

# %%
professor_means[professor_means["avg_rev_len"] < 1000].plot.scatter(x="agg_rating", y="gpa", c="avg_rev_len")

# %% [markdown]
# ## Avg. Grade by Course Type

# %%
df.groupby("reason")["gpa"].mean().drop("N/A").plot.bar(ylim=(2.9, 3.4))

# %% [markdown]
# ## Avg. Grade by Year and Month

# %%
df.groupby("year")["gpa"].mean().plot()

# %%
df.groupby("year")["agg_rating"].mean().plot()

# %%
df.groupby("month")["gpa"].mean()[["Jan", "Feb", "Mar", "Apr","May", "Jun",
                                   "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]].plot.bar(ylim=(3, 3.3))

# %% [markdown]
# ## Average Grade by Course Level

# %%
df.groupby("level")["gpa"].mean().plot.bar(ylim=(3, 3.43))

# %% [markdown]
# ## Polyrating by Keywords

# %%
df["awesome"] = df["review"].str.contains("awesome")
df["shit"] = df["review"].str.contains("shit")

# %%
import seaborn as sns

sns.boxplot(x="awesome", y="agg_rating", data=df)
df.groupby("awesome")["agg_rating"].mean()
# Out:
# awesome
# False    2.602295
# True     3.090410
# Name: agg_rating, dtype: float64

# %%
sns.boxplot(x="shit", y="agg_rating", data=df)
df.groupby("shit")["agg_rating"].mean()
# Out:
# shit
# False    2.635707
# True     2.358353
# Name: agg_rating, dtype: float64

# %%
def gender_finder(review):
    m_total = 0
    m_total += review.lower().split().count("he")
    m_total += review.lower().split().count("his")    
    m_total += review.lower().split().count("him")    
    f_total = 0
    f_total += review.lower().split().count("she")    
    f_total += review.lower().split().count("her")    
    return m_total - f_total
    
df["gender"] = df["review"].apply(gender_finder)

# %%
df.groupby('prof_name')["gender"].sum()
# Out:
# prof_name
# Abel, Christina                -94
# Aberbromby, Kira               -21
# Abitia, Fred                    33
# Abler, Fred                     22
# Abney, Keith                   555
# Abney, Ray                      63
# Abshire, Franklin                4
# Acosta, Kellie                 -17
# Adam, Sandra                   -66
# Adams, Nikki                   -97
# Adan, Elizabeth               -120
# Agalos, Pete                    98
# Agbo, Samuel                   365
# Agrawal, Mohan                 218
# Agronsky, Steve                293
# Aguayo-Vazquez, Jennifer       -34
# Aguilera, Javier               349
# Ahern, James                   157
# Ahler, Michael                   9
# Ahlgren, William L.            257
# Ahmed, Deif                     27
# Ajaib, Muhammad Adeel           30
# Alaniz, Ryan                   211
# Alexander, Benjamin             65
# Alexander, Charlotte           -11
# Alexander, Dekhtyar             66
# Algert, Susan                  -28
# Allebe, Adrienne                -8
# Allen, Regulus                -231
# Allen, Teresa                 -123
#                               ...
# Zhang, Shanju                  133
# Zhang, Xiaozheng              -155
# Zinn, Jesse                     37
# Zohns, Mark                     37
# Zohns, Michael                  33
# Zoller, David                   27
# Zulfacar, Maliha              -470
# Zumwalt, Marta                 -80
# Zweifel, Dick                    7
# abercromby, kira               -46
# aradanas, clarito                9
# blau, jnan                      74
# callow, virginia               -85
# deYong, Ron                     14
# dekhtyar, alexander             19
# del Rio Nascimento, Vicente     69
# gawthrop, william                8
# giardina, charles               18
# john, arun                       0
# killing, ansgar                 16
# kumar, arun                      0
# mitra, arnab                    40
# nirmal, jhon                     0
# raj, arul                        0
# sami, ananthasayanam             0
# schaeffer, robert               80
# singh, arjun                     0
# strong, les                      3
# takemae, seiji                  38
# trudell, carmen                -41
# Name: gender, Length: 2454, dtype: int64
